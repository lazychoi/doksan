# %%
import pandas as pd

# %%
data = pd.read_excel('data/NC Dinos.xlsx', index_col=0, sheet_name=None)

# %%
data
# Out:
# {'2013':     선수명  팀명   경기   타석   타수   안타  홈런  득점  타점  볼넷   삼진  도루  BABIP     타율    출루율  \
#  0   모창민  NC  108  436  395  109  12  57  51  37   68  16  0.307  0.276  0.339
#  1   이호준  NC  126  508  442  123  20  46  87  60  109   2  0.324  0.278  0.362
#  2   김종호  NC  128  546  465  129   0  72  22  57  100  50  0.352  0.277  0.376
#  3   나성범  NC  104  458  404   98  14  55  64  33   95  12  0.279  0.243  0.319
#  4   조영훈  NC  120  426  380  107   6  38  39  39   56   4  0.316  0.282  0.350
#  5   이현곤  NC   91  161  139   38   0  10   9  16   14   2  0.304  0.273  0.361
#  6   이상호  NC  102  138  125   31   0  26  13   9   21  24  0.298  0.248  0.299
#  7   강진성  NC    3    3    2    1   0   1   0   1    0   0  0.500  0.500  0.667
#  8   조평호  NC   26   86   79   21   2  12   7   6   24   1  0.358  0.266  0.318
#  9   박민우  NC   32   48   42   11   0  10   6   5    7   9  0.306  0.262  0.333
#  10  박정준  NC   77  195  167   41   4  24  21  23   44   4  0.303  0.246  0.335
# ...

# %%
nc13, nc14, nc15 = data.values()
nc13
# Out:
#     선수명  팀명   경기   타석   타수   안타  홈런  득점  타점  볼넷   삼진  도루  BABIP     타율    출루율  \
# 0   모창민  NC  108  436  395  109  12  57  51  37   68  16  0.307  0.276  0.339
# 1   이호준  NC  126  508  442  123  20  46  87  60  109   2  0.324  0.278  0.362
# 2   김종호  NC  128  546  465  129   0  72  22  57  100  50  0.352  0.277  0.376
# 3   나성범  NC  104  458  404   98  14  55  64  33   95  12  0.279  0.243  0.319
# 4   조영훈  NC  120  426  380  107   6  38  39  39   56   4  0.316  0.282  0.350
# 5   이현곤  NC   91  161  139   38   0  10   9  16   14   2  0.304  0.273  0.361
# 6   이상호  NC  102  138  125   31   0  26  13   9   21  24  0.298  0.248  0.299
# 7   강진성  NC    3    3    2    1   0   1   0   1    0   0  0.500  0.500  0.667
# 8   조평호  NC   26   86   79   21   2  12   7   6   24   1  0.358  0.266  0.318
# 9   박민우  NC   32   48   42   11   0  10   6   5    7   9  0.306  0.262  0.333
# 10  박정준  NC   77  195  167   41   4  24  21  23   44   4  0.303  0.246  0.335
# ...

# %%
nc13.columns
# Out:
# Index(['선수명', '팀명', '경기', '타석', '타수', '안타', '홈런', '득점', '타점', '볼넷', '삼진', '도루',
#        'BABIP', '타율', '출루율', '장타율', 'OPS', 'wOBA', 'WAR'],
#       dtype='object')

# %%
del nc13['팀명']

# %%
nc13
# Out:
#     선수명   경기   타석   타수   안타  홈런  득점  타점  볼넷   삼진  도루  BABIP     타율    출루율  \
# 0   모창민  108  436  395  109  12  57  51  37   68  16  0.307  0.276  0.339
# 1   이호준  126  508  442  123  20  46  87  60  109   2  0.324  0.278  0.362
# 2   김종호  128  546  465  129   0  72  22  57  100  50  0.352  0.277  0.376
# 3   나성범  104  458  404   98  14  55  64  33   95  12  0.279  0.243  0.319
# 4   조영훈  120  426  380  107   6  38  39  39   56   4  0.316  0.282  0.350
# 5   이현곤   91  161  139   38   0  10   9  16   14   2  0.304  0.273  0.361
# 6   이상호  102  138  125   31   0  26  13   9   21  24  0.298  0.248  0.299
# 7   강진성    3    3    2    1   0   1   0   1    0   0  0.500  0.500  0.667
# 8   조평호   26   86   79   21   2  12   7   6   24   1  0.358  0.266  0.318
# 9   박민우   32   48   42   11   0  10   6   5    7   9  0.306  0.262  0.333
# 10  박정준   77  195  167   41   4  24  21  23   44   4  0.303  0.246  0.335
# 11  이승호    2    1    0    0   0   0   0   1    0   1      -      -  1.000
# ...

# %%
nc13['선수명'].unique(), nc14['선수명'].unique(), nc15['선수명'].unique()
# Out:
# (array(['모창민', '이호준', '김종호', '나성범', '조영훈', '이현곤', '이상호', '강진성', '조평호',
#         '박민우', '박정준', '이승호', '마낙길', '김성욱', '강구성', '지석훈', '김종찬', '차화준',
#         '김동건', '이창섭'], dtype=object),
#  array(['테임즈', '나성범', '박민우', '손시헌', '지석훈', '이호준', '권희동', '모창민', '이종욱',
#         '김준완', '최재원', '마낙길', '조영훈', '김태우', '박명환*', '조평호', '강민국', '허준',
#         '김성욱', '노진혁'], dtype=object),
#  array(['테임즈', '나성범', '박민우', '이호준', '김종호', '조영훈', '손시헌', '이종욱', '모창민',
#         '지석훈', '용덕한', '최재원', '박정준', '김태군', '조평호', '이창섭', '김준완', '강구성',
#         '강민국', '김태진'], dtype=object))
